# %% [markdown]
# # We should improve the code of task 3!!

# %%
import rasterio
from rasterio import plot

dataset = rasterio.open('..\Material\elevation\SZ.asc')

# %%
win = dataset.window(left=445000.0, bottom=85000.0, right=460000.0, top=90000.0)

# %%
temp = dataset.window_transform(win)
print(temp.width)
print(temp.height)
print(temp.bounds)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-2be71f02c48f> in <module>
#       1 temp = dataset.window_transform(win)
# ----> 2 print(temp.width)
#       3 print(temp.height)
#       4 print(temp.bounds)
#
# AttributeError: 'Affine' object has no attribute 'width'

# %%
print(dataset.width)
print(dataset.height)
print(dataset.bounds)
# Out:
# 9000
# 5000
# BoundingBox(left=425000.0, bottom=75000.0, right=470000.0, top=100000.0)

# %%
dataset.crs
# Out:
# CRS.from_wkt('PROJCS["British_National_Grid",GEOGCS["GCS_OSGB_1936",DATUM["OSGB_1936",SPHEROID["Airy_1830",6377563.396,299.3249646]],PRIMEM["Greenwich",0],UNIT["Degree",0.017453292519943295]],PROJECTION["Transverse_Mercator"],PARAMETER["False_Easting",400000],PARAMETER["False_Northing",-100000],PARAMETER["Central_Meridian",-2],PARAMETER["Scale_Factor",0.999601272],PARAMETER["Latitude_Of_Origin",49],UNIT["Meter",1]]')

# %%
from rasterio import plot
import matplotlib.pyplot as plt

fig1 = plt.figure()
ax1 = plt.axes()
rasterio.plot.show(dataset, ax=ax1)

# %%
# !conda install -y rtree=0.8.3
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
from rtree import index
